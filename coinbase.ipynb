# %% [markdown]
# <a href="https://colab.research.google.com/github/princetondalmet/coinbase-API/blob/main/coinbase.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import pandas as pd
from prettytable import PrettyTable
import json

# %%
tableobj = PrettyTable()

# %%
KeyVal = '37d0d5d1-eca3-4739-8723-8b4dce81be2b'

api_endpoint = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest?CMC_PRO_API_KEY='
api_endpoint += KeyVal
api_endpoint
# Out:
# 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest?CMC_PRO_API_KEY=37d0d5d1-eca3-4739-8723-8b4dce81be2b'

# %%
json_data = requests.get(api_endpoint).json()
cryptodata = json_data['data']

# %%
requests.get(api_endpoint).json()
# Out:
# {'data': [{'circulating_supply': 19024631,
#    'cmc_rank': 1,
#    'date_added': '2013-04-28T00:00:00.000Z',
#    'id': 1,
#    'last_updated': '2022-04-28T11:25:00.000Z',
#    'max_supply': 21000000,
#    'name': 'Bitcoin',
#    'num_market_pairs': 9369,
#    'platform': None,
#    'quote': {'USD': {'fully_diluted_market_cap': 832815766076.59,
#      'last_updated': '2022-04-28T11:25:00.000Z',
#      'market_cap': 754476792409.0199,
#      'market_cap_dominance': 41.3984,
#      'percent_change_1h': -0.04755046,
#      'percent_change_24h': 2.10842848,
#      'percent_change_30d': -16.79039375,
#      'percent_change_60d': 0.72358305,
#      'percent_change_7d': -6.37647105,
#      'percent_change_90d': 8.87671205,
#      'price': 39657.8936226947,
#      'volume_24h': 32010321821.41397,
#      'volume_change_24h': -16.7535}},
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'slug': 'bitcoin',
#    'symbol': 'BTC',
#    'tags': ['mineable',
#     'pow',
#     'sha-256',
#     'store-of-value',
#     'state-channel',
#     'coinbase-ventures-portfolio',
#     'three-arrows-capital-portfolio',
#     'polychain-capital-portfolio',
#     'binance-labs-portfolio',
#     'blockchain-capital-portfolio',
#     'boostvc-portfolio',
#     'cms-holdings-portfolio',
#     'dcg-portfolio',
#     'dragonfly-capital-portfolio',
#     'electric-capital-portfolio',
#     'fabric-ventures-portfolio',
#     'framework-ventures-portfolio',
#     'galaxy-digital-portfolio',
#     'huobi-capital-portfolio',
#     'alameda-research-portfolio',
#     'a16z-portfolio',
#     '1confirmation-portfolio',
#     'winklevoss-capital-portfolio',
#     'usv-portfolio',
#     'placeholder-ventures-portfolio',
#     'pantera-capital-portfolio',
#     'multicoin-capital-portfolio',
#     'paradigm-portfolio'],
#    'total_supply': 19024631},
#   {'circulating_supply': 120561033.3115,
#    'cmc_rank': 2,
#    'date_added': '2015-08-07T00:00:00.000Z',
#    'id': 1027,
#    'last_updated': '2022-04-28T11:24:00.000Z',
#    'max_supply': None,
#    'name': 'Ethereum',
#    'num_market_pairs': 5665,
#    'platform': None,
#    'quote': {'USD': {'fully_diluted_market_cap': 353145661619.81,
#      'last_updated': '2022-04-28T11:24:00.000Z',
#      'market_cap': 353145661619.8099,
#      'market_cap_dominance': 19.3999,
#      'percent_change_1h': 0.0080883,
#      'percent_change_24h': 1.83137575,
#      'percent_change_30d': -14.7641187,
#      'percent_change_60d': 4.6530377,
#      'percent_change_7d': -6.65306309,
#      'percent_change_90d': 23.06779888,
#      'price': 2929.18575695489,
#      'volume_24h': 17166897542.725985,
#      'volume_change_24h': -17.955}},
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'slug': 'ethereum',
#    'symbol': 'ETH',
#    'tags': ['mineable',
#     'pow',
#     'smart-contracts',
#     'ethereum-ecosystem',
#     'coinbase-ventures-portfolio',
#     'three-arrows-capital-portfolio',
#     'polychain-capital-portfolio',
#     'binance-labs-portfolio',
#     'blockchain-capital-portfolio',
#     'boostvc-portfolio',
#     'cms-holdings-portfolio',
#     'dcg-portfolio',
#     'dragonfly-capital-portfolio',
#     'electric-capital-portfolio',
#     'fabric-ventures-portfolio',
#     'framework-ventures-portfolio',
#     'hashkey-capital-portfolio',
#     'kenetic-capital-portfolio',
#     'huobi-capital-portfolio',
#     'alameda-research-portfolio',
#     'a16z-portfolio',
#     '1confirmation-portfolio',
#     'winklevoss-capital-portfolio',
#     'usv-portfolio',
#     'placeholder-ventures-portfolio',
#     'pantera-capital-portfolio',
#     'multicoin-capital-portfolio',
#     'paradigm-portfolio',
#     'injective-ecosystem',
#     'bnb-chain'],
#    'total_supply': 120561033.3115},
#   {'circulating_supply': 83152877108.45168,
#    'cmc_rank': 3,
#    'date_added': '2015-02-25T00:00:00.000Z',
#    'id': 825,
#    'last_updated': '2022-04-28T11:24:00.000Z',
#    'max_supply': None,
#    'name': 'Tether',
#    'num_market_pairs': 32496,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'slug': 'ethereum',
#     'symbol': 'ETH',
#     'token_address': '0xdac17f958d2ee523a2206206994597c13d831ec7'},
#    'quote': {'USD': {'fully_diluted_market_cap': 85724261867.3,
#      'last_updated': '2022-04-28T11:24:00.000Z',
#      'market_cap': 83162879102.8696,
#      'market_cap_dominance': 4.5663,
#      'percent_change_1h': 0.00051679,
#      'percent_change_24h': -0.00415661,
#      'percent_change_30d': -0.0311889,
#      'percent_change_60d': -0.03618857,
#      'percent_change_7d': -0.01639958,
#      'percent_change_90d': -0.02742676,
#      'price': 1.0001202844058525,
#      'volume_24h': 63239074381.87855,
#      'volume_change_24h': -14.4197}},
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'slug': 'tether',
#    'symbol': 'USDT',
#    'tags': ['payments',
#     'stablecoin',
#     'asset-backed-stablecoin',
#     'avalanche-ecosystem',
#     'solana-ecosystem',
#     'arbitrum-ecosytem',
#     'moonriver-ecosystem',
#     'injective-ecosystem',
#     'bnb-chain',
#     'usd-stablecoin'],
#    'total_supply': 85713951815.52956},
#   {'circulating_supply': 163276974.63,
#    'cmc_rank': 4,
#    'date_added': '2017-07-25T00:00:00.000Z',
#    'id': 1839,
#    'last_updated': '2022-04-28T11:24:00.000Z',
#    'max_supply': 165116760,
#    'name': 'BNB',
#    'num_market_pairs': 821,
#    'platform': None,
#    'quote': {'USD': {'fully_diluted_market_cap': 66491305131.79,
#      'last_updated': '2022-04-28T11:24:00.000Z',
#      'market_cap': 65750437091.419785,
#      'market_cap_dominance': 3.6086,
#      'percent_change_1h': -0.12800975,
#      'percent_change_24h': 3.26678446,
#      'percent_change_30d': -8.17285074,
#      'percent_change_60d': 6.67189751,
#      'percent_change_7d': -5.18324694,
#      'percent_change_90d': 5.18661029,
#      'price': 402.6926468990258,
#      'volume_24h': 1819384568.3182495,
#      'volume_change_24h': 6.4021}},
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'slug': 'bnb',
#    'symbol': 'BNB',
#    'tags': ['marketplace',
#     'centralized-exchange',
#     'payments',
#     'smart-contracts',
#     'alameda-research-portfolio',
#     'multicoin-capital-portfolio',
#     'moonriver-ecosystem',
#     'bnb-chain'],
#    'total_supply': 163276974.63},
#   {'circulating_supply': 49497245134.91622,
#    'cmc_rank': 5,
#    'date_added': '2018-10-08T00:00:00.000Z',
#    'id': 3408,
#    'last_updated': '2022-04-28T11:24:00.000Z',
#    'max_supply': None,
#    'name': 'USD Coin',
#    'num_market_pairs': 3827,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'slug': 'ethereum',
#     'symbol': 'ETH',
#     'token_address': '0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48'},
#    'quote': {'USD': {'fully_diluted_market_cap': 49493529956.84,
#      'last_updated': '2022-04-28T11:24:00.000Z',
#      'market_cap': 49493529956.83706,
#      'market_cap_dominance': 2.7241,
#      'percent_change_1h': 0.00579039,
#      'percent_change_24h': -0.06632698,
#      'percent_change_30d': 0.0024642,
#      'percent_change_60d': -0.0079846,
#      'percent_change_7d': -0.02551445,
#      'percent_change_90d': 0.01460438,
#      'price': 0.9999249417201092,
#      'volume_24h': 4139120550.2480307,
#      'volume_change_24h': -5.6245}},
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'slug': 'usd-coin',
#    'symbol': 'USDC',
#    'tags': ['medium-of-exchange',
#     'stablecoin',
#     'asset-backed-stablecoin',
#     'fantom-ecosystem',
#     'arbitrum-ecosytem',
#     'moonriver-ecosystem',
#     'bnb-chain',
#     'usd-stablecoin'],
#    'total_supply': 49497245134.91622},
#   {'circulating_supply': 333704011.9775795,
#    'cmc_rank': 6,
#    'date_added': '2020-04-10T00:00:00.000Z',
#    'id': 5426,
#    'last_updated': '2022-04-28T11:24:00.000Z',
#    'max_supply': None,
#    'name': 'Solana',
#    'num_market_pairs': 300,
#    'platform': None,
#    'quote': {'USD': {'fully_diluted_market_cap': 51120645145.19,
#      'last_updated': '2022-04-28T11:24:00.000Z',
#      'market_cap': 33343626532.433582,
#      'market_cap_dominance': 1.8352,
#      'percent_change_1h': -0.00566818,
#      'percent_change_24h': 1.02774624,
#      'percent_change_30d': -10.49422043,
#      'percent_change_60d': 10.77114044,
#      'percent_change_7d': -7.96030947,
#      'percent_change_90d': 13.53543424,
#      'price': 99.91976522797646,
#      'volume_24h': 1232219377.808171,
#      'volume_change_24h': -13.3608}},
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'slug': 'solana',
#    'symbol': 'SOL',
#    'tags': ['pos',
#     'platform',
#     'solana-ecosystem',
#     'cms-holdings-portfolio',
#     'kenetic-capital-portfolio',
#     'alameda-research-portfolio',
#     'multicoin-capital-portfolio',
#     'okex-blockdream-ventures-portfolio'],
#    'total_supply': 511616946.142289},
#   {'circulating_supply': 345757553.676564,
#    'cmc_rank': 7,
#    'date_added': '2019-07-26T00:00:00.000Z',
#    'id': 4172,
#    'last_updated': '2022-04-28T11:25:00.000Z',
#    'max_supply': None,
#    'name': 'Terra',
#    'num_market_pairs': 232,
#    'platform': None,
#    'quote': {'USD': {'fully_diluted_market_cap': 66757816709.57,
#      'last_updated': '2022-04-28T11:25:00.000Z',
#      'market_cap': 31667055087.535156,
#      'market_cap_dominance': 1.7399,
#      'percent_change_1h': -0.1824208,
#      'percent_change_24h': 3.31549212,
#      'percent_change_30d': -11.24668891,
#      'percent_change_60d': 17.75361746,
#      'percent_change_7d': -6.41905982,
#      'percent_change_90d': 82.40350275,
#      'price': 91.58745702243671,
#      'volume_24h': 1652529007.3043137,
#      'volume_change_24h': -42.3279}},
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'slug': 'terra-luna',
#    'symbol': 'LUNA',
#    'tags': ['cosmos-ecosystem',
#     'store-of-value',
#     'defi',
#     'payments',
#     'coinbase-ventures-portfolio',
#     'binance-labs-portfolio',
#     'solana-ecosystem',
#     'arrington-xrp-capital-portfolio',
#     'hashkey-capital-portfolio',
#     'kenetic-capital-portfolio',
#     'huobi-capital-portfolio',
#     'pantera-capital-portfolio',
#     'terra-ecosystem'],
#    'total_supply': 728896935.016036},
#   {'circulating_supply': 48105234849,
#    'cmc_rank': 8,
#    'date_added': '2013-08-04T00:00:00.000Z',
#    'id': 52,
#    'last_updated': '2022-04-28T11:25:00.000Z',
#    'max_supply': 100000000000,
#    'name': 'XRP',
#    'num_market_pairs': 714,
#    'platform': None,
#    'quote': {'USD': {'fully_diluted_market_cap': 64780956527.71,
#      'last_updated': '2022-04-28T11:25:00.000Z',
#      'market_cap': 31163031275.08144,
#      'market_cap_dominance': 1.7119,
#      'percent_change_1h': -0.24774091,
#      'percent_change_24h': 0.48147026,
#      'percent_change_30d': -26.16835828,
#      'percent_change_60d': -14.01788861,
#      'percent_change_7d': -14.29862209,
#      'percent_change_90d': 8.86090024,
#      'price': 0.6478095652770574,
#      'volume_24h': 1544595403.2781408,
#      'volume_change_24h': -29.6436}},
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'slug': 'xrp',
#    'symbol': 'XRP',
#    'tags': ['medium-of-exchange',
#     'enterprise-solutions',
#     'binance-chain',
#     'arrington-xrp-capital-portfolio',
#     'galaxy-digital-portfolio',
#     'a16z-portfolio',
#     'pantera-capital-portfolio'],
#    'total_supply': 99989594553},
#   {'circulating_supply': 33752565071.288,
#    'cmc_rank': 9,
#    'date_added': '2017-10-01T00:00:00.000Z',
#    'id': 2010,
#    'last_updated': '2022-04-28T11:24:00.000Z',
#    'max_supply': 45000000000,
#    'name': 'Cardano',
#    'num_market_pairs': 428,
#    'platform': None,
#    'quote': {'USD': {'fully_diluted_market_cap': 38136515537.85,
#      'last_updated': '2022-04-28T11:24:00.000Z',
#      'market_cap': 28604560495.18912,
#      'market_cap_dominance': 1.5744,
#      'percent_change_1h': -0.06440779,
#      'percent_change_24h': 1.3392648,
#      'percent_change_30d': -30.52602192,
#      'percent_change_60d': -5.57725539,
#      'percent_change_7d': -11.57932636,
#      'percent_change_90d': -16.67377355,
#      'price': 0.8474781230633613,
#      'volume_24h': 859254873.0365113,
#      'volume_change_24h': -25.1132}},
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'slug': 'cardano',
#    'symbol': 'ADA',
#    'tags': ['mineable',
#     'dpos',
#     'pos',
#     'platform',
#     'research',
#     'smart-contracts',
#     'staking',
#     'cardano-ecosystem',
#     'cardano',
#     'bnb-chain'],
#    'total_supply': 34277702081.605},
#   {'circulating_supply': 268610839.1428451,
#    'cmc_rank': 10,
#    'date_added': '2020-07-13T00:00:00.000Z',
#    'id': 5805,
#    'last_updated': '2022-04-28T11:24:00.000Z',
#    'max_supply': None,
#    'name': 'Avalanche',
#    'num_market_pairs': 238,
#    'platform': None,
#    'quote': {'USD': {'fully_diluted_market_cap': 27733048946.25,
#      'last_updated': '2022-04-28T11:24:00.000Z',
#      'market_cap': 18816775562.480537,
#      'market_cap_dominance': 1.0327,
#      'percent_change_1h': 0.03893746,
#      'percent_change_24h': -0.0327531,
#      'percent_change_30d': -25.31421315,
#      'percent_change_60d': -13.67398531,
#      'percent_change_7d': -11.94364705,
#      'percent_change_90d': 11.88737745,
#      'price': 70.05218263911505,
#      'volume_24h': 462098170.70474285,
#      'volume_change_24h': -19.3955}},
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'slug': 'avalanche',
#    'symbol': 'AVAX',
#    'tags': ['defi',
#     'smart-contracts',
#     'polychain-capital-portfolio',
#     'avalanche-ecosystem',
#     'cms-holdings-portfolio',
#     'dragonfly-capital-portfolio',
#     'moonriver-ecosystem',
#     'injective-ecosystem',
#     'bnb-chain'],
#    'total_supply': 395891289.9134107},
#   {'circulating_supply': 132670764299.89409,
#    'cmc_rank': 11,
#    'date_added': '2013-12-15T00:00:00.000Z',
#    'id': 74,
#    'last_updated': '2022-04-28T11:25:00.000Z',
#    'max_supply': None,
#    'name': 'Dogecoin',
#    'num_market_pairs': 468,
#    'platform': None,
#    'quote': {'USD': {'fully_diluted_market_cap': 18642711090.8,
#      'last_updated': '2022-04-28T11:25:00.000Z',
#      'market_cap': 18642711090.799595,
#      'market_cap_dominance': 1.0229,
#      'percent_change_1h': 0.34712971,
#      'percent_change_24h': 1.32634325,
#      'percent_change_30d': -4.08239939,
#      'percent_change_60d': 10.54833108,
#      'percent_change_7d': -0.72896944,
#      'percent_change_90d': 1.19967872,
#      'price': 0.14051860776695985,
#      'volume_24h': 1346019085.6786253,
#      'volume_change_24h': -56.9039}},
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'slug': 'dogecoin',
#    'symbol': 'DOGE',
#    'tags': ['mineable',
#     'pow',
#     'scrypt',
#     'medium-of-exchange',
#     'memes',
#     'payments',
#     'doggone-doggerel',
#     'bnb-chain'],
#    'total_supply': 132670764299.89409},
#   {'circulating_supply': 18446460257.690083,
#    'cmc_rank': 12,
#    'date_added': '2020-09-21T00:00:00.000Z',
#    'id': 7129,
#    'last_updated': '2022-04-28T11:24:00.000Z',
#    'max_supply': None,
#    'name': 'TerraUSD',
#    'num_market_pairs': 526,
#    'platform': None,
#    'quote': {'USD': {'fully_diluted_market_cap': 18446393609.21,
#      'last_updated': '2022-04-28T11:24:00.000Z',
#      'market_cap': 18446393609.21069,
#      'market_cap_dominance': 1.0122,
#      'percent_change_1h': 0.07919252,
#      'percent_change_24h': -0.14823089,
#      'percent_change_30d': 0.07032586,
#      'percent_change_60d': -0.3066611,
#      'percent_change_7d': -0.25033994,
#      'percent_change_90d': 0.45752435,
#      'price': 0.9999963869231027,
#      'volume_24h': 491280668.6689975,
#      'volume_change_24h': -36.3862}},
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'slug': 'terrausd',
#    'symbol': 'UST',
#    'tags': ['cosmos-ecosystem',
#     'stablecoin',
#     'terra-ecosystem',
#     'injective-ecosystem',
#     'bnb-chain',
#     'usd-stablecoin'],
#    'total_supply': 18446460257.690083},
#   {'circulating_supply': 17405297031.339256,
#    'cmc_rank': 13,
#    'date_added': '2019-09-20T00:00:00.000Z',
#    'id': 4687,
#    'last_updated': '2022-04-28T11:25:00.000Z',
#    'max_supply': None,
#    'name': 'Binance USD',
#    'num_market_pairs': 3594,
#    'platform': {'id': 1839,
#     'name': 'BNB Beacon Chain (BEP2)',
#     'slug': 'bnb',
#     'symbol': 'BNB',
#     'token_address': 'BUSD-BD1'},
#    'quote': {'USD': {'fully_diluted_market_cap': 17419757973.01,
#      'last_updated': '2022-04-28T11:25:00.000Z',
#      'market_cap': 17419757973.011997,
#      'market_cap_dominance': 0.956,
#      'percent_change_1h': 0.21261445,
#      'percent_change_24h': 0.18512661,
#      'percent_change_30d': 0.00430481,
#      'percent_change_60d': 0.14332974,
#      'percent_change_7d': -0.0985074,
#      'percent_change_90d': 0.01735657,
#      'price': 1.0008308356729967,
#      'volume_24h': 4201541737.387441,
#      'volume_change_24h': -16.5543}},
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'slug': 'binance-usd',
#    'symbol': 'BUSD',
#    'tags': ['stablecoin',
#     'asset-backed-stablecoin',
#     'binance-chain',
#     'harmony-ecosystem',
#     'moonriver-ecosystem',
#     'bnb-chain',
#     'usd-stablecoin'],
#    'total_supply': 17405297031.339256},
#   {'circulating_supply': 987579314.957085,
#    'cmc_rank': 14,
#    'date_added': '2020-08-19T00:00:00.000Z',
#    'id': 6636,
#    'last_updated': '2022-04-28T11:25:00.000Z',
#    'max_supply': None,
#    'name': 'Polkadot',
#    'num_market_pairs': 335,
#    'platform': None,
#    'quote': {'USD': {'fully_diluted_market_cap': 18917417994.1,
#      'last_updated': '2022-04-28T11:25:00.000Z',
#      'market_cap': 16933193076.93833,
#      'market_cap_dominance': 0.9304,
#      'percent_change_1h': -0.260448,
#      'percent_change_24h': 1.58852919,
#      'percent_change_30d': -24.22736998,
#      'percent_change_60d': -7.10144616,
#      'percent_change_7d': -11.30578724,
#      'percent_change_90d': -2.67541096,
#      'price': 17.146160131628676,
#      'volume_24h': 609973707.2179193,
#      'volume_change_24h': -22.671}},
#    'self_reported_circulating_supply': 904869778,
#    'self_reported_market_cap': 15515042111.859291,
#    'slug': 'polkadot-new',
#    'symbol': 'DOT',
#    'tags': ['substrate',
#     'polkadot',
#     'binance-chain',
#     'polkadot-ecosystem',
#     'three-arrows-capital-portfolio',
#     'polychain-capital-portfolio',
#     'arrington-xrp-capital-portfolio',
#     'blockchain-capital-portfolio',
#     'boostvc-portfolio',
#     'cms-holdings-portfolio',
#     'coinfund-portfolio',
#     'fabric-ventures-portfolio',
#     'fenbushi-capital-portfolio',
#     'hashkey-capital-portfolio',
#     'kenetic-capital-portfolio',
#     '1confirmation-portfolio',
#     'placeholder-ventures-portfolio',
#     'pantera-capital-portfolio',
#     'exnetwork-capital-portfolio',
#     'web3',
#     'spartan-group',
#     'injective-ecosystem',
#     'bnb-chain'],
#    'total_supply': 1103303471.382273},
#   {'circulating_supply': 549063278876301.94,
#    'cmc_rank': 15,
#    'date_added': '2020-08-01T00:00:00.000Z',
#    'id': 5994,
#    'last_updated': '2022-04-28T11:24:00.000Z',
#    'max_supply': None,
#    'name': 'Shiba Inu',
#    'num_market_pairs': 344,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'slug': 'ethereum',
#     'symbol': 'ETH',
#     'token_address': '0x95ad61b0a150d79219dcf64e1e6cc01f0b64c4ce'},
#    'quote': {'USD': {'fully_diluted_market_cap': 13754639666,
#      'last_updated': '2022-04-28T11:24:00.000Z',
#      'market_cap': 12806035194.397736,
#      'market_cap_dominance': 0.7028,
#      'percent_change_1h': 0.23447724,
#      'percent_change_24h': 0.57638694,
#      'percent_change_30d': -16.13250109,
#      'percent_change_60d': -5.37301289,
#      'percent_change_7d': -7.95531186,
#      'percent_change_90d': 13.8778512,
#      'price': 2.3323423159177976e-05,
#      'volume_24h': 561141365.7460505,
#      'volume_change_24h': -23.0635}},
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'slug': 'shiba-inu',
#    'symbol': 'SHIB',
#    'tags': ['memes', 'ethereum-ecosystem', 'doggone-doggerel'],
#    'total_supply': 589735030408322.8},
#   {'circulating_supply': 281406.28000986,
#    'cmc_rank': 16,
#    'date_added': '2019-01-30T00:00:00.000Z',
#    'id': 3717,
#    'last_updated': '2022-04-28T11:24:00.000Z',
#    'max_supply': None,
#    'name': 'Wrapped Bitcoin',
#    'num_market_pairs': 410,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'slug': 'ethereum',
#     'symbol': 'ETH',
#     'token_address': '0x2260fac5e5542a773aa44fbcfedf7c193bc2c599'},
#    'quote': {'USD': {'fully_diluted_market_cap': 11154478809.79,
#      'last_updated': '2022-04-28T11:24:00.000Z',
#      'market_cap': 11154478809.790009,
#      'market_cap_dominance': 0.6122,
#      'percent_change_1h': 0.02279074,
#      'percent_change_24h': 1.94293195,
#      'percent_change_30d': -16.84413539,
#      'percent_change_60d': 0.90345005,
#      'percent_change_7d': -6.27530049,
#      'percent_change_90d': 8.624226,
#      'price': 39638.343570012636,
#      'volume_24h': 174502266.27228475,
#      'volume_change_24h': -23.7169}},
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'slug': 'wrapped-bitcoin',
#    'symbol': 'WBTC',
#    'tags': ['medium-of-exchange',
#     'defi',
#     'wrapped-tokens',
#     'fantom-ecosystem',
#     'arbitrum-ecosytem',
#     'moonriver-ecosystem'],
#    'total_supply': 281406.28000986},
#   {'circulating_supply': 7848866566.62,
#    'cmc_rank': 17,
#    'date_added': '2019-04-28T00:00:00.000Z',
#    'id': 3890,
#    'last_updated': '2022-04-28T11:24:00.000Z',
#    'max_supply': 10000000000,
#    'name': 'Polygon',
#    'num_market_pairs': 377,
#    'platform': None,
#    'quote': {'USD': {'fully_diluted_market_cap': 12653596552.49,
#      'last_updated': '2022-04-28T11:24:00.000Z',
#      'market_cap': 9931639092.834805,
#      'market_cap_dominance': 0.5466,
#      'percent_change_1h': 0.14475326,
#      'percent_change_24h': 0.0287167,
#      'percent_change_30d': -26.27381493,
#      'percent_change_60d': -16.75378131,
#      'percent_change_7d': -12.69749503,
#      'percent_change_90d': -20.67631434,
#      'price': 1.2653596552491426,
#      'volume_24h': 497570989.1038302,
#      'volume_change_24h': -24.37}},
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'slug': 'polygon',
#    'symbol': 'MATIC',
#    'tags': ['platform',
#     'enterprise-solutions',
#     'scaling',
#     'state-channel',
#     'coinbase-ventures-portfolio',
#     'binance-launchpad',
#     'binance-labs-portfolio',
#     'polygon-ecosystem',
#     'moonriver-ecosystem',
#     'injective-ecosystem',
#     'bnb-chain'],
#    'total_supply': 10000000000},
#   {'circulating_supply': 25263013692,
#    'cmc_rank': 18,
#    'date_added': '2018-12-14T00:00:00.000Z',
#    'id': 3635,
#    'last_updated': '2022-04-28T11:24:00.000Z',
#    'max_supply': 30263013692,
#    'name': 'Cronos',
#    'num_market_pairs': 134,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'slug': 'ethereum',
#     'symbol': 'ETH',
#     'token_address': '0xa0b73e1ff0b80914ab6fe0444e65848c4c34450b'},
#    'quote': {'USD': {'fully_diluted_market_cap': 11857889098.21,
#      'last_updated': '2022-04-28T11:24:00.000Z',
#      'market_cap': 9898750259.80853,
#      'market_cap_dominance': 0.5448,
#      'percent_change_1h': 0.09924764,
#      'percent_change_24h': 1.62691575,
#      'percent_change_30d': -20.51034009,
#      'percent_change_60d': -5.95965973,
#      'percent_change_7d': -7.76997451,
#      'percent_change_90d': -0.14764413,
#      'price': 0.3918277676801146,
#      'volume_24h': 53472192.38860979,
#      'volume_change_24h': -6.4597}},
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'slug': 'cronos',
#    'symbol': 'CRO',
#    'tags': ['medium-of-exchange',
#     'cosmos-ecosystem',
#     'centralized-exchange',
#     'mobile',
#     'payments'],
#    'total_supply': 30263013692},
#   {'circulating_supply': 8970030583.040913,
#    'cmc_rank': 19,
#    'date_added': '2019-11-22T00:00:00.000Z',
#    'id': 4943,
#    'last_updated': '2022-04-28T11:24:00.000Z',
#    'max_supply': None,
#    'name': 'Dai',
#    'num_market_pairs': 922,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'slug': 'ethereum',
#     'symbol': 'ETH',
#     'token_address': '0x6b175474e89094c44da98b954eedeac495271d0f'},
#    'quote': {'USD': {'fully_diluted_market_cap': 8964677051.87,
#      'last_updated': '2022-04-28T11:24:00.000Z',
#      'market_cap': 8964677051.872404,
#      'market_cap_dominance': 0.492,
#      'percent_change_1h': -0.00779023,
#      'percent_change_24h': 0.01771693,
#      'percent_change_30d': -0.03113322,
#      'percent_change_60d': -0.0422983,
#      'percent_change_7d': -0.04617432,
#      'percent_change_90d': 0.0603643,
#      'price': 0.9994031758176354,
#      'volume_24h': 232654894.99897432,
#      'volume_change_24h': -26.209}},
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'slug': 'multi-collateral-dai',
#    'symbol': 'DAI',
#    'tags': ['defi',
#     'stablecoin',
#     'ethereum-ecosystem',
#     'avalanche-ecosystem',
#     'polygon-ecosystem',
#     'fantom-ecosystem',
#     'arbitrum-ecosytem',
#     'harmony-ecosystem',
#     'moonriver-ecosystem',
#     'bnb-chain',
#     'usd-stablecoin'],
#    'total_supply': 8970030583.040913},
#   {'circulating_supply': 681397374,
#    'cmc_rank': 20,
#    'date_added': '2020-08-11T00:00:00.000Z',
#    'id': 6535,
#    'last_updated': '2022-04-28T11:25:00.000Z',
#    'max_supply': 1000000000,
#    'name': 'NEAR Protocol',
#    'num_market_pairs': 136,
#    'platform': None,
#    'quote': {'USD': {'fully_diluted_market_cap': 12911999675.52,
#      'last_updated': '2022-04-28T11:25:00.000Z',
#      'market_cap': 8798202671.989187,
#      'market_cap_dominance': 0.4834,
#      'percent_change_1h': -0.27719253,
#      'percent_change_24h': 0.86892849,
#      'percent_change_30d': -2.73692262,
#      'percent_change_60d': 44.2073361,
#      'percent_change_7d': -21.90296639,
#      'percent_change_90d': 26.69182569,
#      'price': 12.911999675521479,
#      'volume_24h': 948389017.2059597,
#      'volume_change_24h': -26.167}},
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'slug': 'near-protocol',
#    'symbol': 'NEAR',
#    'tags': ['platform',
#     'staking',
#     'coinbase-ventures-portfolio',
#     'arrington-xrp-capital-portfolio',
#     'coinfund-portfolio',
#     'electric-capital-portfolio',
#     'fabric-ventures-portfolio',
#     'kenetic-capital-portfolio',
#     'near-protocol-ecosystem',
#     'injective-ecosystem',
#     'bnb-chain'],
#    'total_supply': 1000000000},
#   {'circulating_supply': 70167206.27791464,
#    'cmc_rank': 21,
#    'date_added': '2013-04-28T00:00:00.000Z',
#    'id': 2,
#    'last_updated': '2022-04-28T11:25:00.000Z',
#    'max_supply': 84000000,
#    'name': 'Litecoin',
#    'num_market_pairs': 766,
#    'platform': None,
#    'quote': {'USD': {'fully_diluted_market_cap': 8640310814.55,
#      'last_updated': '2022-04-28T11:25:00.000Z',
#      'market_cap': 7217457990.829953,
#      'market_cap_dominance': 0.3966,
#      'percent_change_1h': 0.89455241,
#      'percent_change_24h': 2.87757142,
#      'percent_change_30d': -21.18717116,
#      'percent_change_60d': -5.07873441,
#      'percent_change_7d': -8.28421298,
#      'percent_change_90d': -3.36582499,
#      'price': 102.8608430303384,
#      'volume_24h': 665145364.6994015,
#      'volume_change_24h': -11.6843}},
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'slug': 'litecoin',
#    'symbol': 'LTC',
#    'tags': ['mineable',
#     'pow',
#     'scrypt',
#     'medium-of-exchange',
#     'binance-chain',
#     'bnb-chain'],
#    'total_supply': 84000000},
#   {'circulating_supply': 101620994722.84613,
#    'cmc_rank': 22,
#    'date_added': '2017-09-13T00:00:00.000Z',
#    'id': 1958,
#    'last_updated': '2022-04-28T11:24:00.000Z',
#    'max_supply': None,
#    'name': 'TRON',
#    'num_market_pairs': 594,
#    'platform': None,
#    'quote': {'USD': {'fully_diluted_market_cap': 6463473644.28,
#      'last_updated': '2022-04-28T11:24:00.000Z',
#      'market_cap': 6463471682.556142,
#      'market_cap_dominance': 0.3547,
#      'percent_change_1h': -0.26987086,
#      'percent_change_24h': 1.12555555,
#      'percent_change_30d': -10.94587847,
#      'percent_change_60d': 4.95202575,
#      'percent_change_7d': -0.06669136,
#      'percent_change_90d': 13.24081466,
#      'price': 0.06360370413795058,
#      'volume_24h': 720702071.9283339,
#      'volume_change_24h': -15.3332}},
#    'self_reported_circulating_supply': 71659659264,
#    'self_reported_market_cap': 4557819766.453805,
#    'slug': 'tron',
#    'symbol': 'TRX',
#    'tags': ['media', 'payments', 'tron-ecosystem', 'bnb-chain'],
#    'total_supply': 101621025565.78656},
#   {'circulating_supply': 286370297,
#    'cmc_rank': 23,
#    'date_added': '2019-03-14T00:00:00.000Z',
#    'id': 3794,
#    'last_updated': '2022-04-28T11:24:00.000Z',
#    'max_supply': None,
#    'name': 'Cosmos',
#    'num_market_pairs': 275,
#    'platform': None,
#    'quote': {'USD': {'fully_diluted_market_cap': 0,
#      'last_updated': '2022-04-28T11:24:00.000Z',
#      'market_cap': 6067202909.118898,
#      'market_cap_dominance': 0.333,
#      'percent_change_1h': -0.05198933,
#      'percent_change_24h': 2.00410513,
#      'percent_change_30d': -30.97396157,
#      'percent_change_60d': -27.09185436,
#      'percent_change_7d': -14.13277371,
#      'percent_change_90d': -25.09544724,
#      'price': 21.186564991825595,
#      'volume_24h': 484412925.43473625,
#      'volume_change_24h': -9.2416}},
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'slug': 'cosmos',
#    'symbol': 'ATOM',
#    'tags': ['platform',
#     'cosmos-ecosystem',
#     'content-creation',
#     'interoperability',
#     'binance-chain',
#     'polychain-capital-portfolio',
#     'dragonfly-capital-portfolio',
#     'hashkey-capital-portfolio',
#     '1confirmation-portfolio',
#     'paradigm-portfolio',
#     'exnetwork-capital-portfolio',
#     'injective-ecosystem',
#     'bnb-chain'],
#    'total_supply': 0},
#   {'circulating_supply': 467009549.5205637,
#    'cmc_rank': 24,
#    'date_added': '2017-09-20T00:00:00.000Z',
#    'id': 1975,
#    'last_updated': '2022-04-28T11:24:00.000Z',
#    'max_supply': 1000000000,
#    'name': 'Chainlink',
#    'num_market_pairs': 635,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'slug': 'ethereum',
#     'symbol': 'ETH',
#     'token_address': '0x514910771af9ca656af840dff83e8264ecf986ca'},
#    'quote': {'USD': {'fully_diluted_market_cap': 12798654738.81,
#      'last_updated': '2022-04-28T11:24:00.000Z',
#      'market_cap': 5977093984.041312,
#      'market_cap_dominance': 0.328,
#      'percent_change_1h': -0.25479822,
#      'percent_change_24h': 1.95280536,
#      'percent_change_30d': -25.35600792,
#      'percent_change_60d': -11.91193901,
#      'percent_change_7d': -9.92703181,
#      'percent_change_90d': -14.08112183,
#      'price': 12.798654738810912,
#      'volume_24h': 406537393.5103902,
#      'volume_change_24h': -10.8266}},
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'slug': 'chainlink',
#    'symbol': 'LINK',
#    'tags': ['platform',
#     'defi',
#     'oracles',
#     'smart-contracts',
#     'substrate',
#     'polkadot',
#     'polkadot-ecosystem',
#     'avalanche-ecosystem',
#     'solana-ecosystem',
#     'framework-ventures-portfolio',
#     'polygon-ecosystem',
#     'fantom-ecosystem',
#     'cardano-ecosystem',
#     'web3',
#     'near-protocol-ecosystem',
#     'arbitrum-ecosytem',
#     'cardano',
#     'injective-ecosystem',
#     'bnb-chain'],
#    'total_supply': 1000000000},
#   {'circulating_supply': 19048800,
#    'cmc_rank': 25,
#    'date_added': '2017-07-23T00:00:00.000Z',
#    'id': 1831,
#    'last_updated': '2022-04-28T11:24:00.000Z',
#    'max_supply': 21000000,
#    'name': 'Bitcoin Cash',
#    'num_market_pairs': 591,
#    'platform': None,
#    'quote': {'USD': {'fully_diluted_market_cap': 6502110126.22,
#      'last_updated': '2022-04-28T11:24:00.000Z',
#      'market_cap': 5897971208.20887,
#      'market_cap_dominance': 0.3246,
#      'percent_change_1h': 0.02751831,
#      'percent_change_24h': 1.79966983,
#      'percent_change_30d': -17.70828922,
#      'percent_change_60d': -2.70564708,
#      'percent_change_7d': -8.35141088,
#      'percent_change_90d': 8.88473531,
#      'price': 309.62429172487873,
#      'volume_24h': 4528245218.957182,
#      'volume_change_24h': -1.2937}},
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'slug': 'bitcoin-cash',
#    'symbol': 'BCH',
#    'tags': ['mineable',
#     'pow',
#     'sha-256',
#     'marketplace',
#     'medium-of-exchange',
#     'store-of-value',
#     'enterprise-solutions',
#     'payments',
#     'binance-chain',
#     'bnb-chain'],
#    'total_supply': 19048800},
#   {'circulating_supply': 284843750,
#    'cmc_rank': 26,
#    'date_added': '2022-03-17T12:26:36.000Z',
#    'id': 18876,
#    'last_updated': '2022-04-28T11:23:00.000Z',
#    'max_supply': 1000000000,
#    'name': 'ApeCoin',
#    'num_market_pairs': 130,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'slug': 'ethereum',
#     'symbol': 'ETH',
#     'token_address': '0x4d224452801aced8b2f0aebe155379bb5d594381'},
#    'quote': {'USD': {'fully_diluted_market_cap': 20285398354.82,
#      'last_updated': '2022-04-28T11:23:00.000Z',
#      'market_cap': 5778168937.630595,
#      'market_cap_dominance': 0.318,
#      'percent_change_1h': 0.04083517,
#      'percent_change_24h': 7.10064494,
#      'percent_change_30d': 42.11486746,
#      'percent_change_60d': 1927.73554342,
#      'percent_change_7d': 29.70083546,
#      'percent_change_90d': 1927.73554342,
#      'price': 20.285398354819424,
#      'volume_24h': 1818955733.142606,
#      'volume_change_24h': 7.0963}},
#    'self_reported_circulating_supply': 284843750,
#    'self_reported_market_cap': 5778168937.630595,
#    'slug': 'apecoin-ape',
#    'symbol': 'APE',
#    'tags': ['collectibles-nfts',
#     'content-creation',
#     'gaming',
#     'entertainment',
#     'dao',
#     'governance',
#     'metaverse',
#     'animoca-brands-portfolio'],
#    'total_supply': 1000000000},
#   {'circulating_supply': 690823145.8832684,
#    'cmc_rank': 27,
#    'date_added': '2020-09-17T00:00:00.000Z',
#    'id': 7083,
#    'last_updated': '2022-04-28T11:24:00.000Z',
#    'max_supply': 1000000000,
#    'name': 'Uniswap',
#    'num_market_pairs': 359,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'slug': 'ethereum',
#     'symbol': 'ETH',
#     'token_address': '0x1f9840a85d5af5bf1d1762f925bdaddc4201f984'},
#    'quote': {'USD': {'fully_diluted_market_cap': 8286029060.68,
#      'last_updated': '2022-04-28T11:24:00.000Z',
#      'market_cap': 5724180662.577427,
#      'market_cap_dominance': 0.3151,
#      'percent_change_1h': -0.12008296,
#      'percent_change_24h': 0.69727701,
#      'percent_change_30d': -27.05983687,
#      'percent_change_60d': -10.21780237,
#      'percent_change_7d': -12.67578128,
#      'percent_change_90d': -17.7293453,
#      'price': 8.286029060677519,
#      'volume_24h': 136156017.13760263,
#      'volume_change_24h': -17.4344}},
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'slug': 'uniswap',
#    'symbol': 'UNI',
#    'tags': ['decentralized-exchange',
#     'defi',
#     'dao',
#     'yield-farming',
#     'amm',
#     'coinbase-ventures-portfolio',
#     'three-arrows-capital-portfolio',
#     'governance',
#     'blockchain-capital-portfolio',
#     'defiance-capital-portfolio',
#     'alameda-research-portfolio',
#     'a16z-portfolio',
#     'pantera-capital-portfolio',
#     'parafi-capital',
#     'paradigm-portfolio',
#     'arbitrum-ecosytem',
#     'injective-ecosystem',
#     'bnb-chain'],
#    'total_supply': 1000000000},
#   {'circulating_supply': 136898555.71874374,
#    'cmc_rank': 28,
#    'date_added': '2019-07-31T00:00:00.000Z',
#    'id': 4195,
#    'last_updated': '2022-04-28T11:25:00.000Z',
#    'max_supply': 352170015,
#    'name': 'FTX Token',
#    'num_market_pairs': 121,
#    'platform': {'id': 1839,
#     'name': 'BNB Beacon Chain (BEP2)',
#     'slug': 'bnb',
#     'symbol': 'BNB',
#     'token_address': 'FTT-F11'},
#    'quote': {'USD': {'fully_diluted_market_cap': 14242195941.96,
#      'last_updated': '2022-04-28T11:25:00.000Z',
#      'market_cap': 5536348841.957254,
#      'market_cap_dominance': 0.3042,
#      'percent_change_1h': -0.1855135,
#      'percent_change_24h': 3.15530733,
#      'percent_change_30d': -21.86406619,
#      'percent_change_60d': -7.37470357,
#      'percent_change_7d': -9.67686646,
#      'percent_change_90d': 5.63580982,
#      'price': 40.44125091671244,
#      'volume_24h': 82928624.65300053,
#      'volume_change_24h': -32.5669}},
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'slug': 'ftx-token',
#    'symbol': 'FTT',
#    'tags': ['marketplace',
#     'centralized-exchange',
#     'derivatives',
#     'cms-holdings-portfolio',
#     'kenetic-capital-portfolio',
#     'alameda-research-portfolio',
#     'pantera-capital-portfolio',
#     'exnetwork-capital-portfolio'],
#    'total_supply': 332767891.7859715},
#   {'circulating_supply': 953954130,
#    'cmc_rank': 29,
#    'date_added': '2019-05-21T00:00:00.000Z',
#    'id': 3957,
#    'last_updated': '2022-04-28T11:24:00.000Z',
#    'max_supply': None,
#    'name': 'UNUS SED LEO',
#    'num_market_pairs': 19,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'slug': 'ethereum',
#     'symbol': 'ETH',
#     'token_address': '0x2af5d2ad76741191d15dfe7bf6ac92d4bd912ca3'},
#    'quote': {'USD': {'fully_diluted_market_cap': 5664255600.1,
#      'last_updated': '2022-04-28T11:24:00.000Z',
#      'market_cap': 5484392374.7997,
#      'market_cap_dominance': 0.3013,
#      'percent_change_1h': -0.13153961,
#      'percent_change_24h': -0.74110157,
#      'percent_change_30d': -4.36433595,
#      'percent_change_60d': -5.35759052,
#      'percent_change_7d': -3.48302726,
#      'percent_change_90d': 66.12548666,
#      'price': 5.749115394887697,
#      'volume_24h': 7431983.39982512,
#      'volume_change_24h': 12.5288}},
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'slug': 'unus-sed-leo',
#    'symbol': 'LEO',
#    'tags': ['marketplace',
#     'centralized-exchange',
#     'discount-token',
#     'payments',
#     'kenetic-capital-portfolio',
#     'alameda-research-portfolio'],
#    'total_supply': 985239504},
#   {'circulating_supply': 24784717044.030582,
#    'cmc_rank': 30,
#    'date_added': '2014-08-05T00:00:00.000Z',
#    'id': 512,
#    'last_updated': '2022-04-28T11:25:00.000Z',
#    'max_supply': 50001806812,
#    'name': 'Stellar',
#    'num_market_pairs': 420,
#    'platform': None,
#    'quote': {'USD': {'fully_diluted_market_cap': 9297250926.98,
#      'last_updated': '2022-04-28T11:25:00.000Z',
#      'market_cap': 4608428138.986944,
#      'market_cap_dominance': 0.2532,
#      'percent_change_1h': -0.144746,
#      'percent_change_24h': 1.82708019,
#      'percent_change_30d': -21.70123183,
#      'percent_change_60d': -2.91875033,
#      'percent_change_7d': -8.09977989,
#      'percent_change_90d': -2.72915459,
#      'price': 0.18593829942863468,
#      'volume_24h': 265078523.80967855,
#      'volume_change_24h': -8.9624}},
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'slug': 'stellar',
#    'symbol': 'XLM',
#    'tags': ['medium-of-exchange',
#     'enterprise-solutions',
#     'decentralized-exchange',
#     'smart-contracts',
#     'hashkey-capital-portfolio'],
#    'total_supply': 50001787867.13164},
#   {'circulating_supply': 6712791677.290724,
#    'cmc_rank': 31,
#    'date_added': '2019-06-20T00:00:00.000Z',
#    'id': 4030,
#    'last_updated': '2022-04-28T11:24:00.000Z',
#    'max_supply': 10000000000,
#    'name': 'Algorand',
#    'num_market_pairs': 208,
#    'platform': None,
#    'quote': {'USD': {'fully_diluted_market_cap': 6780777216.92,
#      'last_updated': '2022-04-28T11:24:00.000Z',
#      'market_cap': 4551794486.72748,
#      'market_cap_dominance': 0.2505,
#      'percent_change_1h': 0.33833059,
#      'percent_change_24h': 3.05568277,
#      'percent_change_30d': -27.98072492,
#      'percent_change_60d': -19.08497098,
#      'percent_change_7d': -10.46613851,
#      'percent_change_90d': -28.09079406,
#      'price': 0.6780777216915779,
#      'volume_24h': 147389125.3142212,
#      'volume_change_24h': -29.1749}},
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'slug': 'algorand',
#    'symbol': 'ALGO',
#    'tags': ['pos',
#     'platform',
#     'research',
#     'smart-contracts',
#     'arrington-xrp-capital-portfolio',
#     'kenetic-capital-portfolio',
#     'usv-portfolio',
#     'multicoin-capital-portfolio',
#     'exnetwork-capital-portfolio'],
#    'total_supply': 7101500354.224518},
#   {'circulating_supply': 18113684.3530176,
#    'cmc_rank': 32,
#    'date_added': '2014-05-21T00:00:00.000Z',
#    'id': 328,
#    'last_updated': '2022-04-28T11:25:00.000Z',
#    'max_supply': None,
#    'name': 'Monero',
#    'num_market_pairs': 176,
#    'platform': None,
#    'quote': {'USD': {'fully_diluted_market_cap': 4285792687.65,
#      'last_updated': '2022-04-28T11:25:00.000Z',
#      'market_cap': 4285792687.647072,
#      'market_cap_dominance': 0.2352,
#      'percent_change_1h': 0.65884068,
#      'percent_change_24h': 4.10480349,
#      'percent_change_30d': 5.80190266,
#      'percent_change_60d': 49.40431885,
#      'percent_change_7d': -14.12235017,
#      'percent_change_90d': 66.43981296,
#      'price': 236.60524298211547,
#      'volume_24h': 228398301.40895718,
#      'volume_change_24h': -20.2497}},
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'slug': 'monero',
#    'symbol': 'XMR',
#    'tags': ['mineable',
#     'pow',
#     'medium-of-exchange',
#     'privacy',
#     'ringct',
#     'boostvc-portfolio',
#     'electric-capital-portfolio',
#     'galaxy-digital-portfolio'],
#    'total_supply': 18113684.3530176},
#   {'circulating_supply': 134486256.27310982,
#    'cmc_rank': 33,
#    'date_added': '2016-07-24T00:00:00.000Z',
#    'id': 1321,
#    'last_updated': '2022-04-28T11:24:00.000Z',
#    'max_supply': 210700000,
#    'name': 'Ethereum Classic',
#    'num_market_pairs': 300,
#    'platform': None,
#    'quote': {'USD': {'fully_diluted_market_cap': 6621381804.11,
#      'last_updated': '2022-04-28T11:24:00.000Z',
#      'market_cap': 4226316327.4311986,
#      'market_cap_dominance': 0.2326,
#      'percent_change_1h': 0.38532523,
#      'percent_change_24h': 1.27469494,
#      'percent_change_30d': -39.39401642,
#      'percent_change_60d': 8.78827255,
#      'percent_change_7d': -15.52731909,
#      'percent_change_90d': 29.89377327,
#      'price': 31.425637418655988,
#      'volume_24h': 430059024.99691683,
#      'volume_change_24h': -19.2208}},
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'slug': 'ethereum-classic',
#    'symbol': 'ETC',
#    'tags': ['mineable',
#     'pow',
#     'ethash',
#     'platform',
#     'smart-contracts',
#     'dcg-portfolio',
#     'bnb-chain'],
#    'total_supply': 210700000},
#   {'circulating_supply': 195451063,
#    'cmc_rank': 34,
#    'date_added': '2017-12-13T00:00:00.000Z',
#    'id': 2280,
#    'last_updated': '2022-04-28T11:25:00.000Z',
#    'max_supply': None,
#    'name': 'Filecoin',
#    'num_market_pairs': 200,
#    'platform': None,
#    'quote': {'USD': {'fully_diluted_market_cap': 3493095087.3,
#      'last_updated': '2022-04-28T11:25:00.000Z',
#      'market_cap': 3493095087.2969995,
#      'market_cap_dominance': 0.1917,
#      'percent_change_1h': -0.04378067,
#      'percent_change_24h': 1.82847562,
#      'percent_change_30d': -32.97323945,
#      'percent_change_60d': -11.0296546,
#      'percent_change_7d': -10.51880135,
#      'percent_change_90d': -4.40391139,
#      'price': 17.87196771243449,
#      'volume_24h': 250065134.23878095,
#      'volume_change_24h': -28.2346}},
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'slug': 'filecoin',
#    'symbol': 'FIL',
#    'tags': ['mineable',
#     'distributed-computing',
#     'filesharing',
#     'storage',
#     'polychain-capital-portfolio',
#     'blockchain-capital-portfolio',
#     'boostvc-portfolio',
#     'dcg-portfolio',
#     'hashkey-capital-portfolio',
#     'a16z-portfolio',
#     'winklevoss-capital-portfolio',
#     'pantera-capital-portfolio',
#     'web3',
#     'bnb-chain'],
#    'total_supply': 195451063},
#   {'circulating_supply': 20227064410.580406,
#    'cmc_rank': 35,
#    'date_added': '2019-09-17T00:00:00.000Z',
#    'id': 4642,
#    'last_updated': '2022-04-28T11:25:00.000Z',
#    'max_supply': 50000000000,
#    'name': 'Hedera',
#    'num_market_pairs': 95,
#    'platform': None,
#    'quote': {'USD': {'fully_diluted_market_cap': 8591694512.78,
#      'last_updated': '2022-04-28T11:25:00.000Z',
#      'market_cap': 3475695166.12245,
#      'market_cap_dominance': 0.1908,
#      'percent_change_1h': -0.0136768,
#      'percent_change_24h': 1.32187921,
#      'percent_change_30d': -29.57124512,
#      'percent_change_60d': -22.64006205,
#      'percent_change_7d': -14.741691,
#      'percent_change_90d': -16.45709132,
#      'price': 0.17183389025569018,
#      'volume_24h': 52332710.93726845,
#      'volume_change_24h': -5.3532}},
#    'self_reported_circulating_supply': 19389577881,
#    'self_reported_market_cap': 3331786597.707912,
#    'slug': 'hedera',
#    'symbol': 'HBAR',
#    'tags': ['dag',
#     'marketplace',
#     'enterprise-solutions',
#     'payments',
#     'dcg-portfolio'],
#    'total_supply': 50000000000},
#   {'circulating_supply': 225367465.2992487,
#    'cmc_rank': 36,
#    'date_added': '2021-03-23T00:00:00.000Z',
#    'id': 8916,
#    'last_updated': '2022-04-28T11:24:00.000Z',
#    'max_supply': None,
#    'name': 'Internet Computer',
#    'num_market_pairs': 112,
#    'platform': None,
#    'quote': {'USD': {'fully_diluted_market_cap': 7401808838.21,
#      'last_updated': '2022-04-28T11:24:00.000Z',
#      'market_cap': 3470721646.373531,
#      'market_cap_dominance': 0.191,
#      'percent_change_1h': 0.440038,
#      'percent_change_24h': 1.26541123,
#      'percent_change_30d': -30.86004969,
#      'percent_change_60d': -17.44117113,
#      'percent_change_7d': -12.62370225,
#      'percent_change_90d': -19.86828374,
#      'price': 15.400278126947107,
#      'volume_24h': 137588108.45100906,
#      'volume_change_24h': -26.4991}},
#    'self_reported_circulating_supply': 225368002.7172529,
#    'self_reported_market_cap': 3470729922.7602663,
#    'slug': 'internet-computer',
#    'symbol': 'ICP',
#    'tags': ['platform',
#     'distributed-computing',
#     'polychain-capital-portfolio',
#     'exnetwork-capital-portfolio'],
#    'total_supply': 480628257.30777603},
#   {'circulating_supply': 1842475468.606961,
#    'cmc_rank': 37,
#    'date_added': '2017-09-17T00:00:00.000Z',
#    'id': 1966,
#    'last_updated': '2022-04-28T11:24:00.000Z',
#    'max_supply': None,
#    'name': 'Decentraland',
#    'num_market_pairs': 263,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'slug': 'ethereum',
#     'symbol': 'ETH',
#     'token_address': '0x0f5d2fb29fb7d3cfee444a200298f468908cc942'},
#    'quote': {'USD': {'fully_diluted_market_cap': 4044352953.84,
#      'last_updated': '2022-04-28T11:24:00.000Z',
#      'market_cap': 3396849107.6946383,
#      'market_cap_dominance': 0.1866,
#      'percent_change_1h': 0.17834402,
#      'percent_change_24h': 0.21847963,
#      'percent_change_30d': -32.99532747,
#      'percent_change_60d': -30.90535493,
#      'percent_change_7d': -14.1770239,
#      'percent_change_90d': -16.43117773,
#      'price': 1.8436332887855984,
#      'volume_24h': 209842823.40200448,
#      'volume_change_24h': -20.9765}},
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'slug': 'decentraland',
#    'symbol': 'MANA',
#    'tags': ['platform',
#     'collectibles-nfts',
#     'gaming',
#     'payments',
#     'metaverse',
#     'boostvc-portfolio',
#     'dcg-portfolio',
#     'fabric-ventures-portfolio',
#     'kenetic-capital-portfolio',
#     'polygon-ecosystem',
#     'play-to-earn'],
#    'total_supply': 2193686227.320146},
#   {'circulating_supply': 64315576989,
#    'cmc_rank': 38,
#    'date_added': '2017-08-22T00:00:00.000Z',
#    'id': 3077,
#    'last_updated': '2022-04-28T11:24:00.000Z',
#    'max_supply': 86712634466,
#    'name': 'VeChain',
#    'num_market_pairs': 182,
#    'platform': None,
#    'quote': {'USD': {'fully_diluted_market_cap': 4559407513.67,
#      'last_updated': '2022-04-28T11:24:00.000Z',
#      'market_cap': 3381755458.998345,
#      'market_cap_dominance': 0.1856,
#      'percent_change_1h': 0.29028329,
#      'percent_change_24h': 1.60744608,
#      'percent_change_30d': -29.23148471,
#      'percent_change_60d': 9.40875336,
#      'percent_change_7d': -15.12919315,
#      'percent_change_90d': 2.05944801,
#      'price': 0.052580659574534054,
#      'volume_24h': 240950430.57450253,
#      'volume_change_24h': -3.8703}},
#    'self_reported_circulating_supply': None,
# ...
#   {'circulating_supply': 8999999999,
#    'cmc_rank': 88,
#    'date_added': '2015-04-01T00:00:00.000Z',
#    'id': 873,
#    'last_updated': '2022-04-28T11:24:00.000Z',
#    'max_supply': 8999999999,
#    'name': 'NEM',
#    'num_market_pairs': 122,
#    'platform': None,
#    'quote': {'USD': {'fully_diluted_market_cap': 840273796.24,
#      'last_updated': '2022-04-28T11:24:00.000Z',
#      'market_cap': 840273796.2351804,
#      'market_cap_dominance': 0.0462,
#      'percent_change_1h': 0.32909119,
#      'percent_change_24h': 2.26473362,
#      'percent_change_30d': -21.88723944,
#      'percent_change_60d': -8.67042613,
#      'percent_change_7d': -8.87930128,
#      'percent_change_90d': -1.84948047,
#      'price': 0.09336375514761601,
#      'volume_24h': 16480695.9278044,
#      'volume_change_24h': -23.4547}},
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'slug': 'nem',
#    'symbol': 'XEM',
#    'tags': ['poi',
#     'medium-of-exchange',
#     'payments',
#     'smart-contracts',
#     'fantom-ecosystem'],
#    'total_supply': 8999999999},
#   {'circulating_supply': 6725002.27425501,
#    'cmc_rank': 89,
#    'date_added': '2020-06-16T00:00:00.000Z',
#    'id': 5692,
#    'last_updated': '2022-04-28T11:24:00.000Z',
#    'max_supply': 10000000,
#    'name': 'Compound',
#    'num_market_pairs': 259,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'slug': 'ethereum',
#     'symbol': 'ETH',
#     'token_address': '0xc00e94cb662c3520282e6f5717214004a7f26888'},
#    'quote': {'USD': {'fully_diluted_market_cap': 1249239346.43,
#      'last_updated': '2022-04-28T11:24:00.000Z',
#      'market_cap': 840113744.5844959,
#      'market_cap_dominance': 0.0461,
#      'percent_change_1h': -0.24183238,
#      'percent_change_24h': 0.53098074,
#      'percent_change_30d': -14.1170585,
#      'percent_change_60d': 10.45789183,
#      'percent_change_7d': -14.89342123,
#      'percent_change_90d': 3.79756603,
#      'price': 124.92393464321363,
#      'volume_24h': 57445572.34497936,
#      'volume_change_24h': -22.7818}},
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'slug': 'compound',
#    'symbol': 'COMP',
#    'tags': ['defi',
#     'dao',
#     'yield-farming',
#     'polkadot-ecosystem',
#     'coinbase-ventures-portfolio',
#     'three-arrows-capital-portfolio',
#     'polychain-capital-portfolio',
#     'lending-borowing',
#     'dragonfly-capital-portfolio',
#     'alameda-research-portfolio',
#     'a16z-portfolio',
#     'pantera-capital-portfolio',
#     'paradigm-portfolio',
#     'bnb-chain'],
#    'total_supply': 10000000},
#   {'circulating_supply': 13972700.51972558,
#    'cmc_rank': 90,
#    'date_added': '2016-02-10T00:00:00.000Z',
#    'id': 1168,
#    'last_updated': '2022-04-28T11:24:00.000Z',
#    'max_supply': 21000000,
#    'name': 'Decred',
#    'num_market_pairs': 57,
#    'platform': None,
#    'quote': {'USD': {'fully_diluted_market_cap': 1255761324.4,
#      'last_updated': '2022-04-28T11:24:00.000Z',
#      'market_cap': 835541757.6215074,
#      'market_cap_dominance': 0.0459,
#      'percent_change_1h': -1.25072829,
#      'percent_change_24h': 0.13845277,
#      'percent_change_30d': -10.45740855,
#      'percent_change_60d': 5.83813495,
#      'percent_change_7d': -0.86312935,
#      'percent_change_90d': 0.66209674,
#      'price': 59.79815830461363,
#      'volume_24h': 4938942.87185531,
#      'volume_change_24h': -15.567}},
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'slug': 'decred',
#    'symbol': 'DCR',
#    'tags': ['mineable',
#     'hybrid-pow-pos',
#     'blake256',
#     'medium-of-exchange',
#     'store-of-value',
#     'privacy',
#     'dao',
#     'placeholder-ventures-portfolio'],
#    'total_supply': 13972700.51972558},
#   {'circulating_supply': 171287601.11586,
#    'cmc_rank': 91,
#    'date_added': '2020-05-31T00:00:00.000Z',
#    'id': 5647,
#    'last_updated': '2022-04-28T11:24:00.000Z',
#    'max_supply': 1000000000,
#    'name': 'Kadena',
#    'num_market_pairs': 27,
#    'platform': None,
#    'quote': {'USD': {'fully_diluted_market_cap': 4773658681.4,
#      'last_updated': '2022-04-28T11:24:00.000Z',
#      'market_cap': 817668544.0836451,
#      'market_cap_dominance': 0.045,
#      'percent_change_1h': -0.17780358,
#      'percent_change_24h': 0.84218102,
#      'percent_change_30d': -31.28461361,
#      'percent_change_60d': -24.36486759,
#      'percent_change_7d': -14.81806184,
#      'percent_change_90d': -15.55466291,
#      'price': 4.773658681404319,
#      'volume_24h': 31074791.12109765,
#      'volume_change_24h': -33.1314}},
#    'self_reported_circulating_supply': 171287601.11586,
#    'self_reported_market_cap': 817668544.0836451,
#    'slug': 'kadena',
#    'symbol': 'KDA',
#    'tags': ['mineable',
#     'pow',
#     'blake2s',
#     'platform',
#     'cosmos-ecosystem',
#     'smart-contracts',
#     'coinfund-portfolio',
#     'multicoin-capital-portfolio'],
#    'total_supply': 1000000000},
#   {'circulating_supply': 5301214400,
#    'cmc_rank': 92,
#    'date_added': '2019-03-28T00:00:00.000Z',
#    'id': 3822,
#    'last_updated': '2022-04-28T11:24:00.000Z',
#    'max_supply': None,
#    'name': 'Theta Fuel',
#    'num_market_pairs': 38,
#    'platform': None,
#    'quote': {'USD': {'fully_diluted_market_cap': 813555300.16,
#      'last_updated': '2022-04-28T11:24:00.000Z',
#      'market_cap': 813555300.1646026,
#      'market_cap_dominance': 0.0448,
#      'percent_change_1h': -0.08221961,
#      'percent_change_24h': 0.57009641,
#      'percent_change_30d': -21.64257317,
#      'percent_change_60d': -8.51433824,
#      'percent_change_7d': -12.15084745,
#      'percent_change_90d': -12.83491645,
#      'price': 0.15346583608552083,
#      'volume_24h': 31856887.01425343,
#      'volume_change_24h': 40.0664}},
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'slug': 'theta-fuel',
#    'symbol': 'TFUEL',
#    'tags': ['media', 'content-creation', 'defi', 'payments'],
#    'total_supply': 5301214400},
#   {'circulating_supply': 163295557,
#    'cmc_rank': 93,
#    'date_added': '2020-05-19T00:00:00.000Z',
#    'id': 5604,
#    'last_updated': '2022-04-28T11:24:00.000Z',
#    'max_supply': None,
#    'name': 'Secret',
#    'num_market_pairs': 35,
#    'platform': None,
#    'quote': {'USD': {'fully_diluted_market_cap': 912126916.2,
#      'last_updated': '2022-04-28T11:24:00.000Z',
#      'market_cap': 783247315.9705915,
#      'market_cap_dominance': 0.0431,
#      'percent_change_1h': -0.35839722,
#      'percent_change_24h': 8.34757402,
#      'percent_change_30d': -11.67658155,
#      'percent_change_60d': -10.55191394,
#      'percent_change_7d': -7.80306098,
#      'percent_change_90d': -12.73406662,
#      'price': 4.796501082822428,
#      'volume_24h': 39575189.31162325,
#      'volume_change_24h': -1.2677}},
#    'self_reported_circulating_supply': 167986369,
#    'self_reported_market_cap': 805746800.8079079,
#    'slug': 'secret',
#    'symbol': 'SCRT',
#    'tags': ['cosmos-ecosystem', 'defi', 'privacy'],
#    'total_supply': 190165060},
#   {'circulating_supply': 3493014306.28,
#    'cmc_rank': 94,
#    'date_added': '2020-11-12T00:00:00.000Z',
#    'id': 7653,
#    'last_updated': '2022-04-28T11:24:00.000Z',
#    'max_supply': 10000000000,
#    'name': 'Oasis Network',
#    'num_market_pairs': 49,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'slug': 'ethereum',
#     'symbol': 'ETH',
#     'token_address': '0x26B80FBfC01b71495f477d5237071242e0d959d7'},
#    'quote': {'USD': {'fully_diluted_market_cap': 2212135630.02,
#      'last_updated': '2022-04-28T11:24:00.000Z',
#      'market_cap': 772702140.3098338,
#      'market_cap_dominance': 0.0425,
#      'percent_change_1h': 0.67353082,
#      'percent_change_24h': -1.54733643,
#      'percent_change_30d': -21.91231682,
#      'percent_change_60d': -3.64358305,
#      'percent_change_7d': -4.29214118,
#      'percent_change_90d': -26.48744488,
#      'price': 0.22121356300219341,
#      'volume_24h': 74388501.96733715,
#      'volume_change_24h': -59.4588}},
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'slug': 'oasis-network',
#    'symbol': 'ROSE',
#    'tags': ['cosmos-ecosystem',
#     'collectibles-nfts',
#     'defi',
#     'privacy',
#     'scaling',
#     'smart-contracts',
#     'polychain-capital-portfolio',
#     'binance-labs-portfolio',
#     'arrington-xrp-capital-portfolio',
#     'blockchain-capital-portfolio',
#     'dragonfly-capital-portfolio',
#     'electric-capital-portfolio',
#     'kenetic-capital-portfolio',
#     'huobi-capital-portfolio',
#     'a16z-portfolio',
#     'winklevoss-capital-portfolio',
#     'pantera-capital-portfolio'],
#    'total_supply': 10000000000},
#   {'circulating_supply': 173305412321.07236,
#    'cmc_rank': 95,
#    'date_added': '2018-04-29T00:00:00.000Z',
#    'id': 2682,
#    'last_updated': '2022-04-28T11:24:00.000Z',
#    'max_supply': None,
#    'name': 'Holo',
#    'num_market_pairs': 112,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'slug': 'ethereum',
#     'symbol': 'ETH',
#     'token_address': '0x6c6ee5e31d828de241282b9606c8e98ea48526e2'},
#    'quote': {'USD': {'fully_diluted_market_cap': 790629587.73,
#      'last_updated': '2022-04-28T11:24:00.000Z',
#      'market_cap': 771426774.4398768,
#      'market_cap_dominance': 0.0423,
#      'percent_change_1h': 0.22201829,
#      'percent_change_24h': 1.3833457,
#      'percent_change_30d': -31.79998908,
#      'percent_change_60d': 2.95022386,
#      'percent_change_7d': -13.03361381,
#      'percent_change_90d': 3.43588172,
#      'price': 0.004451256103939221,
#      'volume_24h': 46089421.3052633,
#      'volume_change_24h': -15.7867}},
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'slug': 'holo',
#    'symbol': 'HOT',
#    'tags': ['platform', 'distributed-computing', 'filesharing', 'storage'],
#    'total_supply': 177619433541.14133},
#   {'circulating_supply': 847496054.8027713,
#    'cmc_rank': 96,
#    'date_added': '2017-08-16T00:00:00.000Z',
#    'id': 1896,
#    'last_updated': '2022-04-28T11:24:00.000Z',
#    'max_supply': 1000000000,
#    'name': '0x',
#    'num_market_pairs': 241,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'slug': 'ethereum',
#     'symbol': 'ETH',
#     'token_address': '0xe41d2489571d322189246dafa5ebde1f4699f498'},
#    'quote': {'USD': {'fully_diluted_market_cap': 886736798.93,
#      'last_updated': '2022-04-28T11:24:00.000Z',
#      'market_cap': 751505938.7444415,
#      'market_cap_dominance': 0.0414,
#      'percent_change_1h': 0.59850371,
#      'percent_change_24h': 4.01219885,
#      'percent_change_30d': 21.48135433,
#      'percent_change_60d': 62.76878449,
#      'percent_change_7d': -12.82664093,
#      'percent_change_90d': 72.06745856,
#      'price': 0.8867367989333371,
#      'volume_24h': 394758915.8636913,
#      'volume_change_24h': -43.8756}},
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'slug': '0x',
#    'symbol': 'ZRX',
#    'tags': ['platform',
#     'decentralized-exchange',
#     'defi',
#     'scaling',
#     'dao',
#     'substrate',
#     'polkadot',
#     'polkadot-ecosystem',
#     'polychain-capital-portfolio',
#     'governance',
#     'blockchain-capital-portfolio',
#     'boostvc-portfolio',
#     'fabric-ventures-portfolio',
#     'kenetic-capital-portfolio',
#     'placeholder-ventures-portfolio',
#     'pantera-capital-portfolio'],
#    'total_supply': 1000000000},
#   {'circulating_supply': 230354316,
#    'cmc_rank': 97,
#    'date_added': '2022-01-11T12:55:50.000Z',
#    'id': 6836,
#    'last_updated': '2022-04-28T11:24:00.000Z',
#    'max_supply': 1000000000,
#    'name': 'Moonbeam',
#    'num_market_pairs': 38,
#    'platform': None,
#    'quote': {'USD': {'fully_diluted_market_cap': 3144651856.24,
#      'last_updated': '2022-04-28T11:24:00.000Z',
#      'market_cap': 724384127.4015201,
#      'market_cap_dominance': 0.0398,
#      'percent_change_1h': 0.93075849,
#      'percent_change_24h': 4.88204098,
#      'percent_change_30d': -4.28130241,
#      'percent_change_60d': 22.86444168,
#      'percent_change_7d': -24.54693516,
#      'percent_change_90d': -48.70409056,
#      'price': 3.1446518562366337,
#      'volume_24h': 75584919.08986945,
#      'volume_change_24h': 5.9952}},
#    'self_reported_circulating_supply': 1868966.698,
#    'self_reported_market_cap': 5877249.596110152,
#    'slug': 'moonbeam',
#    'symbol': 'GLMR',
#    'tags': ['smart-contracts',
#     'substrate',
#     'polkadot',
#     'polkadot-ecosystem',
#     'binance-labs-portfolio',
#     'arrington-xrp-capital-portfolio',
#     'injective-ecosystem'],
#    'total_supply': 1017068229},
#   {'circulating_supply': 620805326,
#    'cmc_rank': 98,
#    'date_added': '2020-10-20T00:00:00.000Z',
#    'id': 7455,
#    'last_updated': '2022-04-28T11:24:00.000Z',
#    'max_supply': None,
#    'name': 'Audius',
#    'num_market_pairs': 93,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'slug': 'ethereum',
#     'symbol': 'ETH',
#     'token_address': '0x18aaa7115705e8be94bffebde57af9bfc265b998'},
#    'quote': {'USD': {'fully_diluted_market_cap': 1199793423,
#      'last_updated': '2022-04-28T11:24:00.000Z',
#      'market_cap': 682450371.3107378,
#      'market_cap_dominance': 0.0375,
#      'percent_change_1h': 0.68241193,
#      'percent_change_24h': 0.83414676,
#      'percent_change_30d': -4.34424598,
#      'percent_change_60d': 41.20665708,
#      'percent_change_7d': -15.6681424,
#      'percent_change_90d': 28.60319221,
#      'price': 1.0992985123177532,
#      'volume_24h': 47545052.22251412,
#      'volume_change_24h': 2.3443}},
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'slug': 'audius',
#    'symbol': 'AUDIO',
#    'tags': ['music',
#     'coinbase-ventures-portfolio',
#     'binance-labs-portfolio',
#     'solana-ecosystem',
#     'pantera-capital-portfolio',
#     'multicoin-capital-portfolio',
#     'web3'],
#    'total_supply': 1091417308},
#   {'circulating_supply': 919483096,
#    'cmc_rank': 99,
#    'date_added': '2017-10-27T00:00:00.000Z',
#    'id': 2099,
#    'last_updated': '2022-04-28T11:25:00.000Z',
#    'max_supply': None,
#    'name': 'ICON',
#    'num_market_pairs': 80,
#    'platform': None,
#    'quote': {'USD': {'fully_diluted_market_cap': 683414236.77,
#      'last_updated': '2022-04-28T11:25:00.000Z',
#      'market_cap': 678450459.5520209,
#      'market_cap_dominance': 0.0373,
#      'percent_change_1h': 0.20933419,
#      'percent_change_24h': 1.53413919,
#      'percent_change_30d': -26.0325745,
#      'percent_change_60d': 8.08181214,
#      'percent_change_7d': -11.69419932,
#      'percent_change_90d': 9.2213924,
#      'price': 0.7378607203367455,
#      'volume_24h': 12411638.29243299,
#      'volume_change_24h': -49.2526}},
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'slug': 'icon',
#    'symbol': 'ICX',
#    'tags': ['platform',
#     'enterprise-solutions',
#     'interoperability',
#     'smart-contracts',
#     'kenetic-capital-portfolio',
#     'pantera-capital-portfolio'],
#    'total_supply': 926210351},
#   {'circulating_supply': 9540779324.30788,
#    'cmc_rank': 100,
#    'date_added': '2018-05-25T00:00:00.000Z',
#    'id': 2777,
#    'last_updated': '2022-04-28T11:24:00.000Z',
#    'max_supply': 10000000000,
#    'name': 'IoTeX',
#    'num_market_pairs': 87,
#    'platform': None,
#    'quote': {'USD': {'fully_diluted_market_cap': 704825393.76,
#      'last_updated': '2022-04-28T11:24:00.000Z',
#      'market_cap': 672458354.4046429,
#      'market_cap_dominance': 0.037,
#      'percent_change_1h': 0.10679977,
#      'percent_change_24h': 1.49438294,
#      'percent_change_30d': -25.08330755,
#      'percent_change_60d': -4.62383674,
#      'percent_change_7d': -10.04525799,
#      'percent_change_90d': -3.6449363,
#      'price': 0.07048253937614528,
#      'volume_24h': 36121964.27491867,
#      'volume_change_24h': -21.9799}},
#    'self_reported_circulating_supply': 6116124331.505642,
#    'self_reported_market_cap': 431079974.0247466,
#    'slug': 'iotex',
#    'symbol': 'IOTX',
#    'tags': ['platform',
#     'iot',
#     'hashkey-capital-portfolio',
#     'kenetic-capital-portfolio',
#     'iotex-ecosystem',
#     'bnb-chain'],
#    'total_supply': 9626124332.32}],
#  'status': {'credit_count': 1,
#   'elapsed': 30,
#   'error_code': 0,
#   'error_message': None,
#   'notice': None,
#   'timestamp': '2022-04-28T11:25:16.499Z',
#   'total_count': 10069}}

# %%
for currency in cryptodata:
    curr_name = currency['name']
    curr_price = currency['quote']['USD']['price']
    curr_change_1h = currency['quote']['USD']['percent_change_1h']
    curr_change_24h = currency['quote']['USD']['percent_change_24h']
    curr_change_7d = currency['quote']['USD']['percent_change_7d']
    tableobj.add_row([curr_name, curr_price, curr_change_1h, curr_change_24h, curr_change_7d])

# %%
tableobj.field_names =  ["Currency Name", "Currency Price", "Currency 1h Change", "Currency 24h change", "Currency 7d change"]

# %%
print(tableobj)
# Out:
# +--------------------------+------------------------+--------------------+---------------------+--------------------+
# |      Currency Name       |     Currency Price     | Currency 1h Change | Currency 24h change | Currency 7d change |
# +--------------------------+------------------------+--------------------+---------------------+--------------------+
# |         Bitcoin          |   39660.880788960494   |     0.01247362     |      2.05659402     |    -6.39452525     |
# |         Ethereum         |   2929.603873117916    |     0.04729156     |      1.83284567     |    -6.64407409     |
# |          Tether          |   1.0001266088291527   |     0.00200878     |     -0.00385407     |    -0.01625237     |
# |           BNB            |   402.68935450238547   |    -0.10176177     |      3.35785152     |    -5.19041538     |
# |         USD Coin         |   0.9999345573586665   |     0.00625409     |     -0.05370209     |    -0.02589861     |
# |          Solana          |   99.92898915473931    |     0.01623127     |      1.08104621     |    -7.95174016     |
# |          Terra           |    91.6537380373505    |     0.33807031     |      3.34357903     |    -6.50648133     |
# |           XRP            |   0.6482877732712191   |    -0.10430196     |      0.39367502     |    -14.26818935    |
# |         Cardano          |   0.8475521794415989   |    -0.02419913     |      1.35668641     |    -11.57476742    |
# |        Avalanche         |   70.06965851517694    |     0.09627279     |      0.01787822     |    -11.91150782    |
# |         Dogecoin         |  0.14057259442888126   |     0.46638579     |      1.33496751     |    -0.71867979     |
# |         TerraUSD         |   0.9997419407498706   |     0.05510099     |     -0.18272448     |    -0.27025564     |
# |       Binance USD        |   1.000807016777235    |     0.04879219     |      0.02405532     |     0.05565038     |
# |         Polkadot         |   17.153841902422055   |    -0.11136625     |      1.42385533     |    -11.28893777    |
# |        Shiba Inu         | 2.332587032775624e-05  |     0.26404509     |      0.57274891     |    -7.95555441     |
# |     Wrapped Bitcoin      |   39641.10112897808    |      0.007892      |      1.95439665     |    -6.27430171     |
# |         Polygon          |   1.2653966376364212   |     0.16144043     |      0.05580289     |    -12.69325772    |
# |          Cronos          |   0.3919141266382711   |     0.14500376     |      1.68470485     |     -7.7457147     |
# |           Dai            |   0.999453652013932    |    -0.00338825     |      0.02576048     |     -0.0357475     |
# |      NEAR Protocol       |   12.94430468905228    |     0.14954733     |      0.7303798      |    -21.67660931    |
# |         Litecoin         |   102.83856624750254   |     1.25342754     |      2.72765881     |    -8.32532206     |
# |           TRON           |  0.06360467315251171   |    -0.24965203     |      1.16806843     |     -0.0751614     |
# |          Cosmos          |   21.19028519719958    |     0.00108878     |      2.03704605     |    -14.12171713    |
# |        Chainlink         |   12.79851423630006    |    -0.25777647     |      1.97797932     |    -9.92627134     |
# |       Bitcoin Cash       |   309.6344546660723    |     0.02880699     |      1.82402738     |     -8.3482747     |
# |         ApeCoin          |   20.285398354819424   |     0.04083517     |      7.10064494     |    29.70083546     |
# |         Uniswap          |    8.28674028247671    |    -0.11093567     |      0.75641956     |    -12.66035302    |
# |        FTX Token         |    40.4626088496563    |    -0.02181611     |      3.06349992     |    -9.67277334     |
# |       UNUS SED LEO       |   5.753997611723685    |    -0.03934516     |     -0.62245554     |    -3.39370769     |
# |         Stellar          |  0.18594417599449317   |     -0.0734114     |      1.83988843     |     -8.0950221     |
# |         Algorand         |   0.6782064927371914   |     0.39163753     |      3.12513626     |    -10.42575693    |
# |          Monero          |   236.80318023546084   |     0.81911485     |      4.06157094     |    -14.02935557    |
# |     Ethereum Classic     |   31.426135107780432   |     0.43591793     |      1.30638191     |    -15.52999241    |
# |         Filecoin         |   17.87663925353826    |     0.0756715      |      1.41857599     |    -10.5633239     |
# |          Hedera          |  0.17194760410656287   |     0.12320342     |      1.26674124     |    -14.69022679    |
# |    Internet Computer     |   15.400407684020234   |     0.48357406     |      1.32638615     |    -12.60856689    |
# |       Decentraland       |   1.8437314240698535   |     0.20195417     |      0.2522425      |    -14.16464575    |
# |         VeChain          |   0.0525882417542609   |     0.3114639      |      1.59479974     |    -15.10946666    |
# |          Elrond          |   150.66148956226962   |     0.38022981     |      1.85016254     |    -9.06947557     |
# |       The Sandbox        |   2.548673988138759    |     0.19899392     |      1.42738648     |    -12.66451937    |
# |      Theta Network       |   2.8240101373299544   |     0.45940768     |      2.03088891     |    -15.58177901    |
# |        THORChain         |   7.814468020021938    |     0.8081775      |      2.57417073     |    -18.44245561    |
# |          Fantom          |   1.0031548842333586   |     0.18085897     |      1.65904214     |    -16.4352121     |
# |          Tezos           |   2.8349293591018587   |    -0.08246148     |      0.68849599     |    -11.30603561    |
# |          STEPN           |   4.054522154592767    |     0.98035595     |     22.32766358     |    23.39324425     |
# |      Axie Infinity       |   39.31082518446754    |     0.36319523     |      0.40133353     |    -16.8962448     |
# |           Aave           |   174.14690771067205   |    -0.21488088     |      3.6349776      |    -8.59215467     |
# |          Klaytn          |   0.843505725592348    |     0.22641891     |      0.77327988     |    -12.8411999     |
# |       PancakeSwap        |   8.047450887935364    |    -1.96964993     |      4.98228526     |    -15.29481128    |
# |           EOS            |   2.3320233140461393   |     1.44891488     |      4.72654884     |    -15.83053628    |
# |          Zcash           |   150.64809727823447   |     0.10547003     |      2.59803753     |    -9.19993043     |
# |           Flow           |    5.31274334794308    |    -0.09369222     |      1.66848215     |    -10.74863163    |
# |       KuCoin Token       |   19.37369965409693    |    -0.10190841     |      2.50082289     |    -7.80150133     |
# |          Helium          |   16.24738641039019    |     0.58759768     |     -0.96472873     |    -15.80995566    |
# |        The Graph         |  0.39604749911002535   |     0.37139772     |     14.38386764     |     6.82540031     |
# |          Waves           |   16.347254603668183   |    -0.10533322     |      6.13431491     |    -19.09308959    |
# |           IOTA           |   0.6212192352048519   |     0.20777972     |      2.30221625     |    -10.70292804    |
# |      BitTorrent-New      | 1.7808164602496536e-06 |     0.14034433     |      -0.5810256     |    -7.13484273     |
# |          Maker           |   1684.655005834544    |     0.31710655     |      2.20340189     |    -8.44443002     |
# |      Convex Finance      |   27.307716544309947   |    -0.38216554     |      6.58484783     |    -8.39534634     |
# |          eCash           | 8.232688625776334e-05  |     0.02523491     |      1.85758994     |    -16.30817725    |
# |        Bitcoin SV        |   78.43937830318028    |     0.16369255     |      1.15543257     |    -8.88315243     |
# |       Huobi Token        |   9.422120117300945    |     0.29316675     |      1.58343594     |    -1.24710957     |
# |          Stacks          |   1.0646037740701355   |    -0.65657535     |      2.03962461     |    -11.5257109     |
# |           Neo            |   19.213837692704537   |     0.36746977     |       1.81805       |    -13.58213517    |
# |          Kusama          |   159.0682463156706    |     0.18877245     |      1.78491459     |    -13.47144237    |
# |         TrueUSD          |   0.9994458772129968   |    -0.00482216     |      0.00839889     |    -0.05992684     |
# |          Chiliz          |  0.20729127109397047   |    -0.25850629     |      3.95717442     |    -10.85128497    |
# |          Quant           |   102.30518966813717   |     0.31966282     |      1.37890615     |    -10.01948025    |
# |         Harmony          |  0.10321800976750613   |     0.21176834     |      1.75045135     |    -18.61254405    |
# |           Celo           |    2.82793329906224    |     0.09439937     |      2.60091746     |    -13.26915715    |
# |           Nexo           |   2.180004958840953    |     -0.2472236     |      0.15277146     |    -7.23112082     |
# |         Zilliqa          |  0.09511502875283549   |     0.1512243      |      0.18500244     |    -24.43542715    |
# |           Gala           |   0.1727043657507809   |     0.39028476     |      2.33161251     |    -13.62424817    |
# |        Enjin Coin        |   1.3113067277575499   |     0.23771999     |      0.93794015     |    -15.43154347    |
# |     Curve DAO Token      |    2.49862201087877    |    -0.01747869     |      1.61445959     |     4.39898701     |
# |           OKB            |   19.18637173808536    |    -1.36625591     |     -2.01051369     |    -1.86684918     |
# |         Loopring         |   0.8597718540945894   |     0.7281302      |      2.15540934     |    -10.9592791     |
# |           Dash           |   98.28824522392748    |    -0.42292821     |      3.73030931     |    -9.15947203     |
# |  Basic Attention Token   |   0.6715080604147613   |     0.3194003      |      0.53733158     |    -16.77810583    |
# |           Mina           |   2.0358643856717817   |    -0.27524028     |     -0.29221057     |    -18.86751827    |
# |           Kava           |   5.340387015824621    |     0.41777171     |      6.54878749     |     9.83720551     |
# |        Pax Dollar        |   1.0016159577921955   |     0.34482585     |      0.1321209      |     0.59012196     |
# | Kyber Network Crystal v2 |   5.311768588164034    |    -0.10734645     |     -2.42452241     |    22.03351686     |
# |       Neutrino USD       |   0.9743586927658067   |     0.03797793     |     -0.07322753     |    -1.15749886     |
# |         Arweave          |   27.255153865990337   |     1.30830816     |     -1.78518553     |    -10.56906996    |
# |           Amp            |  0.021455386204446338  |     0.08103654     |      2.85679631     |    -6.60513991     |
# |           NEM            |  0.09337533698377964   |     0.28855337     |      2.33409173     |    -8.87413203     |
# |         Compound         |   124.92228087483814   |    -0.21902385     |      0.5007571      |    -14.89882954    |
# |          Decred          |   59.81259931322046    |    -1.21463568     |      0.10902542     |     -0.8550088     |
# |          Kadena          |   4.774029791970657    |    -0.16741775     |      0.85199543     |    -14.8026189     |
# |        Theta Fuel        |  0.15347551583167643   |    -0.10116046     |      0.5863176      |    -12.11746767    |
# |          Secret          |   4.796758014645204    |    -0.34293688     |      8.33140587     |    -7.78789825     |
# |      Oasis Network       |  0.22105476648544636   |     0.60947468     |     -1.64098099     |    -4.31798742     |
# |           Holo           |  0.004449352162815551  |     0.18980558     |      1.31581515     |    -13.0765845     |
# |            0x            |   0.8867374364075368   |     0.80535084     |      4.06400893     |    -12.83329937    |
# |         Moonbeam         |   3.143411213821399    |     0.53239362     |      4.84187674     |    -24.59730074    |
# |          Audius          |   1.0993691791345377   |     0.70785787     |      0.82974929     |    -15.67149506    |
# |           ICON           |   0.7382677616462006   |     0.36323741     |      1.3884541      |    -11.69334367    |
# |          IoTeX           |   0.0704815896472923   |     0.12213329     |      1.51061623     |    -10.04369872    |
# +--------------------------+------------------------+--------------------+---------------------+--------------------+

# %%
table_txt = tableobj.get_string()
with open('output.txt', 'w') as file:
    file.write(table_txt)
